# %%
df = pd.read_csv('heart_cleveland_upload.csv')
max_size = df.shape[0]
max_size
# Out:
# 297

# %%
n_rows = random.randint(80, max_size)
n_rows
# Out:
# 120

# %%
df = df.sample(n=n_rows, random_state=2, ignore_index=True)
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     44    0   2       118   242    0        0      149      0      0.3
# 1     57    0   3       128   303    0        2      159      0      0.0
# 2     61    1   3       120   260    0        0      140      1      3.6
# 3     52    1   1       134   201    0        0      158      0      0.8
# 4     57    1   2       150   168    0        0      174      0      1.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 115   57    1   3       165   289    1        2      124      0      1.0
# 116   60    0   2       102   318    0        0      160      0      0.0
# 117   56    0   3       134   409    0        2      150      1      1.9
# 118   37    0   2       120   215    0        0      170      0      0.0
# 119   53    0   3       130   264    0        2      143      0      0.4
#
#      slope  ca  thal  condition
# 0        1   1     0          0
# ...

# %%
df.columns.drop(['condition'])
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal'],
#       dtype='object')

# %%
df_1 = df.columns.drop['condition']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/l9/bj7gtp716j143vph9qm_q5000000gn/T/ipykernel_57340/376754963.py in <module>
# ----> 1 df_1 = df.columns.drop['condition']
#
# TypeError: 'method' object is not subscriptable

# %%
import click
import os
import pandas as pd
import random
